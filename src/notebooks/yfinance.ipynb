# %%
import pandas as pd
import yfinance as yf

# %%
df = pd.read_csv('AAPL.csv')

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2023-05-02  170.089996  170.350006  167.539993  168.539993  167.645157
# 1  2023-05-03  169.500000  170.919998  167.160004  167.449997  166.560944
# 2  2023-05-04  164.889999  167.039993  164.309998  165.789993  164.909760
# 3  2023-05-05  170.979996  174.300003  170.759995  173.570007  172.648468
# 4  2023-05-08  172.479996  173.850006  172.110001  173.500000  172.578812
#
#       Volume
# 0   48425700
# 1   65136000
# 2   81235400
# 3  113316400
# 4   55962800

# %%
print(df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
stock_date_ranges = df.groupby(['Date']).agg(['min', 'max'])

# %%
for stock_symbol, date_range in stock_date_ranges.iterrows():
    start_date = df['Date'].min()
    end_date = df['Date'].max()

# %%
    print(f"Stock: {stock_symbol}, Date Range: {start_date} to {end_date}")
    print(df.head())
    print("\n")
# Out:
# Stock: 2024-05-02 00:00:00, Date Range: 2023-05-02 00:00:00 to 2024-05-02 00:00:00
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-05-02  170.089996  170.350006  167.539993  168.539993  167.645157
# 1 2023-05-03  169.500000  170.919998  167.160004  167.449997  166.560944
# 2 2023-05-04  164.889999  167.039993  164.309998  165.789993  164.909760
# 3 2023-05-05  170.979996  174.300003  170.759995  173.570007  172.648468
# 4 2023-05-08  172.479996  173.850006  172.110001  173.500000  172.578812
#
#       Volume
# 0   48425700
# 1   65136000
# 2   81235400
# 3  113316400
# 4   55962800
