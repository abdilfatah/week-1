# %%
import talib as tb
import pandas as pd
import yfinance as yf
import plotly.express as px

# %%
tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
tickers.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                   Biotechnology
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
apple = yf.Ticker("AAPL")

# %%
hist = apple.history(period="max")

# %%
hist.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1980-12-12 00:00:00-05:00  0.099192  0.099623  0.099192  0.099192  469033600
# 1980-12-15 00:00:00-05:00  0.094448  0.094448  0.094017  0.094017  175884800
# 1980-12-16 00:00:00-05:00  0.087548  0.087548  0.087117  0.087117  105728000
# 1980-12-17 00:00:00-05:00  0.089273  0.089704  0.089273  0.089273   86441600
# 1980-12-18 00:00:00-05:00  0.091861  0.092292  0.091861  0.091861   73449600
#
#                            Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00        0.0           0.0
# 1980-12-15 00:00:00-05:00        0.0           0.0
# 1980-12-16 00:00:00-05:00        0.0           0.0
# 1980-12-17 00:00:00-05:00        0.0           0.0
# 1980-12-18 00:00:00-05:00        0.0           0.0

# %%
start_date = pd.Timestamp.now() - pd.DateOffset(months=1)
end_date = pd.Timestamp.now()
apple_data = yf.download('AAPL', start=start_date, end=end_date,interval='1h')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
def calculate_indicators(data):
    data['SMA'] = tb.SMA(data['Close'], timeperiod=20)
    data['RSI'] = tb.RSI(data['Close'], timeperiod=14)
    return data

apple_data = calculate_indicators(apple_data)

# %%
apple_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-04-08 09:30:00-04:00  169.059998  169.190002  168.240005  168.820007
# 2024-04-08 10:30:00-04:00  168.824997  169.130005  168.649994  168.815002
# 2024-04-08 11:30:00-04:00  168.815002  168.815002  168.264999  168.412399
# 2024-04-08 12:30:00-04:00  168.414993  168.835007  168.404999  168.645004
# 2024-04-08 13:30:00-04:00  168.645004  168.899994  168.470001  168.790100
#
#                             Adj Close   Volume  SMA  RSI
# Datetime
# 2024-04-08 09:30:00-04:00  168.820007  8279940  NaN  NaN
# 2024-04-08 10:30:00-04:00  168.815002  4718366  NaN  NaN
# 2024-04-08 11:30:00-04:00  168.412399  4134102  NaN  NaN
# 2024-04-08 12:30:00-04:00  168.645004  2982857  NaN  NaN
# 2024-04-08 13:30:00-04:00  168.790100  2336490  NaN  NaN

# %%
def plot_data(data, title):
    fig = px.line(data, x = data.index, y = [data.SMA,data.RSI], title=title)
    fig.show()

# %%
plot_data(apple_data, 'Apple Stock Analysis')
# Out:
# <div>                            <div id="f4bd6465-d66a-42d1-9e3f-00953f55309e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4bd6465-d66a-42d1-9e3f-00953f55309e")) {                    Plotly.newPlot(                        "f4bd6465-d66a-42d1-9e3f-00953f55309e",                        [{"hovertemplate":"variable=SMA\u003cbr\u003eDatetime=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"SMA","orientation":"v","showlegend":true,"x":["2024-04-08T09:30:00-04:00","2024-04-08T10:30:00-04:00","2024-04-08T11:30:00-04:00","2024-04-08T12:30:00-04:00","2024-04-08T13:30:00-04:00","2024-04-08T14:30:00-04:00","2024-04-08T15:30:00-04:00","2024-04-09T09:30:00-04:00","2024-04-09T10:30:00-04:00","2024-04-09T11:30:00-04:00","2024-04-09T12:30:00-04:00","2024-04-09T13:30:00-04:00","2024-04-09T14:30: